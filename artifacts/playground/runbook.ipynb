# %% [markdown]
# # Intelligent routing Playground

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %% [markdown]
# ## Example of vLLM metrics that can be gather

# %%
request = "Analyze the following metrics" 
request += """# HELP python_gc_objects_collected_total Objects collected during gc
        # TYPE python_gc_objects_collected_total counter
        python_gc_objects_collected_total{generation="0"} 13215.0
        python_gc_objects_collected_total{generation="1"} 1496.0
        python_gc_objects_collected_total{generation="2"} 1375.0
        # HELP python_gc_objects_uncollectable_total Uncollectable objects found during GC
        # TYPE python_gc_objects_uncollectable_total counter
        python_gc_objects_uncollectable_total{generation="0"} 0.0
        python_gc_objects_uncollectable_total{generation="1"} 0.0
        python_gc_objects_uncollectable_total{generation="2"} 0.0
        # HELP python_gc_collections_total Number of times this generation was collected
        # TYPE python_gc_collections_total counter
        python_gc_collections_total{generation="0"} 1504.0
        python_gc_collections_total{generation="1"} 137.0
        python_gc_collections_total{generation="2"} 10.0
        # HELP python_info Python platform information
        # TYPE python_info gauge
        python_info{implementation="CPython",major="3",minor="12",patchlevel="12",version="3.12.12"} 1.0
        # HELP process_virtual_memory_bytes Virtual memory size in bytes.
        # TYPE process_virtual_memory_bytes gauge
        process_virtual_memory_bytes 1.39938816e+010
        # HELP process_resident_memory_bytes Resident memory size in bytes.
        # TYPE process_resident_memory_bytes gauge
        process_resident_memory_bytes 1.278119936e+09
        # HELP process_start_time_seconds Start time of the process since unix epoch in seconds.
        # TYPE process_start_time_seconds gauge
        process_start_time_seconds 1.76851643979e+09
        # HELP process_cpu_seconds_total Total user and system CPU time spent in seconds.
        # TYPE process_cpu_seconds_total counter
        process_cpu_seconds_total 125.33
        # HELP process_open_fds Number of open file descriptors.
        # TYPE process_open_fds gauge
        process_open_fds 75.0
        # HELP process_max_fds Maximum number of open file descriptors.
        # TYPE process_max_fds gauge
        process_max_fds 1.048576e+06
        # HELP vllm:num_requests_running Number of requests in model execution batches.
        # TYPE vllm:num_requests_running gauge
        vllm:num_requests_running{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:num_requests_waiting Number of requests waiting to be processed.
        # TYPE vllm:num_requests_waiting gauge
        vllm:num_requests_waiting{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:engine_sleep_state Engine sleep state; awake = 0 means engine is sleeping; awake = 1 means engine is awake; weights_offloaded = 1 means sleep level 1; discard_all = 1 means sleep level 2.
        # TYPE vllm:engine_sleep_state gauge
        vllm:engine_sleep_state{engine="0",model_name="openai/gpt-oss-120b",sleep_state="awake"} 1.0
        vllm:engine_sleep_state{engine="0",model_name="openai/gpt-oss-120b",sleep_state="weights_offloaded"} 0.0
        vllm:engine_sleep_state{engine="0",model_name="openai/gpt-oss-120b",sleep_state="discard_all"} 0.0
        # HELP vllm:kv_cache_usage_perc KV-cache usage. 1 means 100 percent usage.
        # TYPE vllm:kv_cache_usage_perc gauge
        vllm:kv_cache_usage_perc{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:prefix_cache_queries_total Prefix cache queries, in terms of number of queried tokens.
        # TYPE vllm:prefix_cache_queries_total counter
        vllm:prefix_cache_queries_total{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:prefix_cache_queries_created Prefix cache queries, in terms of number of queried tokens.
        # TYPE vllm:prefix_cache_queries_created gauge
        vllm:prefix_cache_queries_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040389647e+09
        # HELP vllm:prefix_cache_hits_total Prefix cache hits, in terms of number of cached tokens.
        # TYPE vllm:prefix_cache_hits_total counter
        vllm:prefix_cache_hits_total{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:prefix_cache_hits_created Prefix cache hits, in terms of number of cached tokens.
        # TYPE vllm:prefix_cache_hits_created gauge
        vllm:prefix_cache_hits_created{engine="0",model_name="openai/gpt-oss-120b"} 1.768516804038977e+09
        # HELP vllm:external_prefix_cache_queries_total External prefix cache queries from KV connector cross-instance cache sharing, in terms of number of queried tokens.
        # TYPE vllm:external_prefix_cache_queries_total counter
        vllm:external_prefix_cache_queries_total{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:external_prefix_cache_queries_created External prefix cache queries from KV connector cross-instance cache sharing, in terms of number of queried tokens.
        # TYPE vllm:external_prefix_cache_queries_created gauge
        vllm:external_prefix_cache_queries_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040389876e+09
        # HELP vllm:external_prefix_cache_hits_total External prefix cache hits from KV connector cross-instance cache sharing, in terms of number of cached tokens.
        # TYPE vllm:external_prefix_cache_hits_total counter
        vllm:external_prefix_cache_hits_total{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:external_prefix_cache_hits_created External prefix cache hits from KV connector cross-instance cache sharing, in terms of number of cached tokens.
        # TYPE vllm:external_prefix_cache_hits_created gauge
        vllm:external_prefix_cache_hits_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040389972e+09
        # HELP vllm:mm_cache_queries_total Multi-modal cache queries, in terms of number of queried items.
        # TYPE vllm:mm_cache_queries_total counter
        vllm:mm_cache_queries_total{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:mm_cache_queries_created Multi-modal cache queries, in terms of number of queried items.
        # TYPE vllm:mm_cache_queries_created gauge
        vllm:mm_cache_queries_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040390103e+09
        # HELP vllm:mm_cache_hits_total Multi-modal cache hits, in terms of number of cached items.
        # TYPE vllm:mm_cache_hits_total counter
        vllm:mm_cache_hits_total{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:mm_cache_hits_created Multi-modal cache hits, in terms of number of cached items.
        # TYPE vllm:mm_cache_hits_created gauge
        vllm:mm_cache_hits_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040390217e+09
        # HELP vllm:num_preemptions_total Cumulative number of preemption from the engine.
        # TYPE vllm:num_preemptions_total counter
        vllm:num_preemptions_total{engine="0",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:num_preemptions_created Cumulative number of preemption from the engine.
        # TYPE vllm:num_preemptions_created gauge
        vllm:num_preemptions_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040390308e+09
        # HELP vllm:prompt_tokens_total Number of prefill tokens processed.
        # TYPE vllm:prompt_tokens_total counter
        vllm:prompt_tokens_total{engine="0",model_name="openai/gpt-oss-120b"} 2384.0
        # HELP vllm:prompt_tokens_created Number of prefill tokens processed.
        # TYPE vllm:prompt_tokens_created gauge
        vllm:prompt_tokens_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040390391e+09
        # HELP vllm:generation_tokens_total Number of generation tokens processed.
        # TYPE vllm:generation_tokens_total counter
        vllm:generation_tokens_total{engine="0",model_name="openai/gpt-oss-120b"} 6351.0
        # HELP vllm:generation_tokens_created Number of generation tokens processed.
        # TYPE vllm:generation_tokens_created gauge
        vllm:generation_tokens_created{engine="0",model_name="openai/gpt-oss-120b"} 1.768516804039051e+09
        # HELP vllm:request_success_total Count of successfully processed requests.
        # TYPE vllm:request_success_total counter
        vllm:request_success_total{engine="0",finished_reason="stop",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_success_total{engine="0",finished_reason="length",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_success_total{engine="0",finished_reason="abort",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_success_total{engine="0",finished_reason="error",model_name="openai/gpt-oss-120b"} 0.0
        # HELP vllm:request_success_created Count of successfully processed requests.
        # TYPE vllm:request_success_created gauge
        vllm:request_success_created{engine="0",finished_reason="stop",model_name="openai/gpt-oss-120b"} 1.7685168040390773e+09
        vllm:request_success_created{engine="0",finished_reason="length",model_name="openai/gpt-oss-120b"} 1.7685168040390837e+09
        vllm:request_success_created{engine="0",finished_reason="abort",model_name="openai/gpt-oss-120b"} 1.7685168040390909e+09
        vllm:request_success_created{engine="0",finished_reason="error",model_name="openai/gpt-oss-120b"} 1.7685168040390959e+09
        # HELP vllm:request_prompt_tokens Number of prefill tokens processed.
        # TYPE vllm:request_prompt_tokens histogram
        vllm:request_prompt_tokens_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prompt_tokens_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prompt_tokens_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prompt_tokens_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prompt_tokens_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prompt_tokens_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prompt_tokens_bucket{engine="0",le="100.0",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_prompt_tokens_bucket{engine="0",le="200.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_bucket{engine="0",le="500.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_bucket{engine="0",le="1000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_bucket{engine="0",le="2000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_bucket{engine="0",le="5000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_bucket{engine="0",le="10000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_bucket{engine="0",le="20000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_bucket{engine="0",le="50000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_bucket{engine="0",le="100000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prompt_tokens_sum{engine="0",model_name="openai/gpt-oss-120b"} 2384.0
        # HELP vllm:request_prompt_tokens_created Number of prefill tokens processed.
        # TYPE vllm:request_prompt_tokens_created gauge
        vllm:request_prompt_tokens_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040391624e+09
        # HELP vllm:request_generation_tokens Number of generation tokens processed.
        # TYPE vllm:request_generation_tokens histogram
        vllm:request_generation_tokens_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_generation_tokens_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_generation_tokens_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_generation_tokens_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_generation_tokens_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_generation_tokens_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_generation_tokens_bucket{engine="0",le="100.0",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_generation_tokens_bucket{engine="0",le="200.0",model_name="openai/gpt-oss-120b"} 11.0
        vllm:request_generation_tokens_bucket{engine="0",le="500.0",model_name="openai/gpt-oss-120b"} 21.0
        vllm:request_generation_tokens_bucket{engine="0",le="1000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_generation_tokens_bucket{engine="0",le="2000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_generation_tokens_bucket{engine="0",le="5000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_generation_tokens_bucket{engine="0",le="10000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_generation_tokens_bucket{engine="0",le="20000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_generation_tokens_bucket{engine="0",le="50000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_generation_tokens_bucket{engine="0",le="100000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_generation_tokens_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_generation_tokens_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_generation_tokens_sum{engine="0",model_name="openai/gpt-oss-120b"} 6351.0
        # HELP vllm:request_generation_tokens_created Number of generation tokens processed.
        # TYPE vllm:request_generation_tokens_created gauge
        vllm:request_generation_tokens_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040392265e+09
        # HELP vllm:iteration_tokens_total Histogram of number of tokens per engine_step.
        # TYPE vllm:iteration_tokens_total histogram
        vllm:iteration_tokens_total_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:iteration_tokens_total_bucket{engine="0",le="8.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:iteration_tokens_total_bucket{engine="0",le="16.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:iteration_tokens_total_bucket{engine="0",le="32.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:iteration_tokens_total_bucket{engine="0",le="64.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:iteration_tokens_total_bucket{engine="0",le="128.0",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_bucket{engine="0",le="256.0",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_bucket{engine="0",le="512.0",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_bucket{engine="0",le="1024.0",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_bucket{engine="0",le="2048.0",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_bucket{engine="0",le="4096.0",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_bucket{engine="0",le="8192.0",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_bucket{engine="0",le="16384.0",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_count{engine="0",model_name="openai/gpt-oss-120b"} 6351.0
        vllm:iteration_tokens_total_sum{engine="0",model_name="openai/gpt-oss-120b"} 8735.0
        # HELP vllm:iteration_tokens_total_created Histogram of number of tokens per engine_step.
        # TYPE vllm:iteration_tokens_total_created gauge
        vllm:iteration_tokens_total_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040392723e+09
        # HELP vllm:request_max_num_generation_tokens Histogram of maximum number of requested generation tokens.
        # TYPE vllm:request_max_num_generation_tokens histogram
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="100.0",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="200.0",model_name="openai/gpt-oss-120b"} 11.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="500.0",model_name="openai/gpt-oss-120b"} 21.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="1000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="2000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="5000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="10000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="20000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="50000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="100000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_max_num_generation_tokens_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_max_num_generation_tokens_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_max_num_generation_tokens_sum{engine="0",model_name="openai/gpt-oss-120b"} 6351.0
        # HELP vllm:request_max_num_generation_tokens_created Histogram of maximum number of requested generation tokens.
        # TYPE vllm:request_max_num_generation_tokens_created gauge
        vllm:request_max_num_generation_tokens_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040393057e+09
        # HELP vllm:request_params_n Histogram of the n request parameter.
        # TYPE vllm:request_params_n histogram
        vllm:request_params_n_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_params_n_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_params_n_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_params_n_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_params_n_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_params_n_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_params_n_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_params_n_sum{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        # HELP vllm:request_params_n_created Histogram of the n request parameter.
        # TYPE vllm:request_params_n_created gauge
        vllm:request_params_n_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040393343e+09
        # HELP vllm:request_params_max_tokens Histogram of the max_tokens request parameter.
        # TYPE vllm:request_params_max_tokens histogram
        vllm:request_params_max_tokens_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="100.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="200.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="500.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="1000.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="2000.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="5000.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="10000.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="20000.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="50000.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="100000.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_params_max_tokens_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_params_max_tokens_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_params_max_tokens_sum{engine="0",model_name="openai/gpt-oss-120b"} 3.143344e+06
        # HELP vllm:request_params_max_tokens_created Histogram of the max_tokens request parameter.
        # TYPE vllm:request_params_max_tokens_created gauge
        vllm:request_params_max_tokens_created{engine="0",model_name="openai/gpt-oss-120b"} 1.768516804039358e+09
        # HELP vllm:time_to_first_token_seconds Histogram of time to first token in seconds.
        # TYPE vllm:time_to_first_token_seconds histogram
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.001",model_name="openai/gpt-oss-120b"} 0.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.005",model_name="openai/gpt-oss-120b"} 0.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.01",model_name="openai/gpt-oss-120b"} 0.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.02",model_name="openai/gpt-oss-120b"} 0.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.04",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.06",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.08",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.1",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.25",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="0.75",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="2.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="7.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="40.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="80.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="160.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="640.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="2560.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:time_to_first_token_seconds_sum{engine="0",model_name="openai/gpt-oss-120b"} 0.607799768447876
        # HELP vllm:time_to_first_token_seconds_created Histogram of time to first token in seconds.
        # TYPE vllm:time_to_first_token_seconds_created gauge
        vllm:time_to_first_token_seconds_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040393946e+09
        # HELP vllm:inter_token_latency_seconds Histogram of inter-token latency in seconds.
        # TYPE vllm:inter_token_latency_seconds histogram
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.01",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.025",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.05",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.075",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.1",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.15",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.2",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.3",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.4",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.5",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="0.75",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="2.5",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="7.5",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="40.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="80.0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_count{engine="0",model_name="openai/gpt-oss-120b"} 6327.0
        vllm:inter_token_latency_seconds_sum{engine="0",model_name="openai/gpt-oss-120b"} 30.50264041990158
        # HELP vllm:inter_token_latency_seconds_created Histogram of inter-token latency in seconds.
        # TYPE vllm:inter_token_latency_seconds_created gauge
        vllm:inter_token_latency_seconds_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040394342e+09
        # HELP vllm:request_time_per_output_token_seconds Histogram of time_per_output_token_seconds per request.
        # TYPE vllm:request_time_per_output_token_seconds histogram
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.01",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.025",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.05",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.075",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.1",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.15",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.2",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.3",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.4",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="0.75",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="2.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="7.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="40.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="80.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_time_per_output_token_seconds_sum{engine="0",model_name="openai/gpt-oss-120b"} 0.11563240826354527
        # HELP vllm:request_time_per_output_token_seconds_created Histogram of time_per_output_token_seconds per request.
        # TYPE vllm:request_time_per_output_token_seconds_created gauge
        vllm:request_time_per_output_token_seconds_created{engine="0",model_name="openai/gpt-oss-120b"} 1.768516804039468e+09
        # HELP vllm:e2e_request_latency_seconds Histogram of e2e request latency in seconds.
        # TYPE vllm:e2e_request_latency_seconds histogram
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="0.3",model_name="openai/gpt-oss-120b"} 2.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="0.5",model_name="openai/gpt-oss-120b"} 2.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="0.8",model_name="openai/gpt-oss-120b"} 7.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 11.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="1.5",model_name="openai/gpt-oss-120b"} 19.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 21.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="2.5",model_name="openai/gpt-oss-120b"} 21.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="15.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="30.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="40.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="60.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="120.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="240.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="480.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="960.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="1920.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="7680.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:e2e_request_latency_seconds_sum{engine="0",model_name="openai/gpt-oss-120b"} 31.109687566757202
        # HELP vllm:e2e_request_latency_seconds_created Histogram of e2e request latency in seconds.
        # TYPE vllm:e2e_request_latency_seconds_created gauge
        vllm:e2e_request_latency_seconds_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040396187e+09
        # HELP vllm:request_queue_time_seconds Histogram of time spent in WAITING phase for request.
        # TYPE vllm:request_queue_time_seconds histogram
        vllm:request_queue_time_seconds_bucket{engine="0",le="0.3",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="0.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="0.8",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="1.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="2.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="15.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="30.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="40.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="60.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="120.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="240.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="480.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="960.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="1920.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="7680.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_queue_time_seconds_sum{engine="0",model_name="openai/gpt-oss-120b"} 0.0004284180176910013
        # HELP vllm:request_queue_time_seconds_created Histogram of time spent in WAITING phase for request.
        # TYPE vllm:request_queue_time_seconds_created gauge
        vllm:request_queue_time_seconds_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040396585e+09
        # HELP vllm:request_inference_time_seconds Histogram of time spent in RUNNING phase for request.
        # TYPE vllm:request_inference_time_seconds histogram
        vllm:request_inference_time_seconds_bucket{engine="0",le="0.3",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="0.5",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="0.8",model_name="openai/gpt-oss-120b"} 7.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 11.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="1.5",model_name="openai/gpt-oss-120b"} 19.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 21.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="2.5",model_name="openai/gpt-oss-120b"} 21.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="15.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="30.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="40.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="60.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="120.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="240.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="480.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="960.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="1920.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="7680.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_inference_time_seconds_sum{engine="0",model_name="openai/gpt-oss-120b"} 31.04982925695367
        # HELP vllm:request_inference_time_seconds_created Histogram of time spent in RUNNING phase for request.
        # TYPE vllm:request_inference_time_seconds_created gauge
        vllm:request_inference_time_seconds_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040397024e+09
        # HELP vllm:request_prefill_time_seconds Histogram of time spent in PREFILL phase for request.
        # TYPE vllm:request_prefill_time_seconds histogram
        vllm:request_prefill_time_seconds_bucket{engine="0",le="0.3",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="0.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="0.8",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="1.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="2.5",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="15.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="30.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="40.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="60.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="120.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="240.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="480.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="960.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="1920.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="7680.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_time_seconds_sum{engine="0",model_name="openai/gpt-oss-120b"} 0.5471888370520901
        # HELP vllm:request_prefill_time_seconds_created Histogram of time spent in PREFILL phase for request.
        # TYPE vllm:request_prefill_time_seconds_created gauge
        vllm:request_prefill_time_seconds_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040397348e+09
        # HELP vllm:request_decode_time_seconds Histogram of time spent in DECODE phase for request.
        # TYPE vllm:request_decode_time_seconds histogram
        vllm:request_decode_time_seconds_bucket{engine="0",le="0.3",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="0.5",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="0.8",model_name="openai/gpt-oss-120b"} 8.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 12.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="1.5",model_name="openai/gpt-oss-120b"} 20.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 21.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="2.5",model_name="openai/gpt-oss-120b"} 21.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="15.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="30.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="40.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="60.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="120.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="240.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="480.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="960.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="1920.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="7680.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_decode_time_seconds_sum{engine="0",model_name="openai/gpt-oss-120b"} 30.50264041990158
        # HELP vllm:request_decode_time_seconds_created Histogram of time spent in DECODE phase for request.
        # TYPE vllm:request_decode_time_seconds_created gauge
        vllm:request_decode_time_seconds_created{engine="0",model_name="openai/gpt-oss-120b"} 1.768516804039769e+09
        # HELP vllm:request_prefill_kv_computed_tokens Histogram of new KV tokens computed during prefill (excluding cached tokens).
        # TYPE vllm:request_prefill_kv_computed_tokens histogram
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="1.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="2.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="5.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="10.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="20.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="50.0",model_name="openai/gpt-oss-120b"} 0.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="100.0",model_name="openai/gpt-oss-120b"} 2.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="200.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="500.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="1000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="2000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="5000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="10000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="20000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="50000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="100000.0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_bucket{engine="0",le="+Inf",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_count{engine="0",model_name="openai/gpt-oss-120b"} 24.0
        vllm:request_prefill_kv_computed_tokens_sum{engine="0",model_name="openai/gpt-oss-120b"} 2384.0
        # HELP vllm:request_prefill_kv_computed_tokens_created Histogram of new KV tokens computed during prefill (excluding cached tokens).
        # TYPE vllm:request_prefill_kv_computed_tokens_created gauge
        vllm:request_prefill_kv_computed_tokens_created{engine="0",model_name="openai/gpt-oss-120b"} 1.7685168040398023e+09
        # HELP vllm:cache_config_info Information of the LLMEngine CacheConfig
        # TYPE vllm:cache_config_info gauge
        vllm:cache_config_info{block_size="16",cache_dtype="auto",calculate_kv_scales="False",cpu_kvcache_space_bytes="None",cpu_offload_gb="0.0",enable_prefix_caching="False",engine="0",gpu_memory_utilization="0.9",is_attention_free="False",kv_cache_memory_bytes="None",kv_offloading_backend="None",kv_offloading_size="None",kv_sharing_fast_prefill="False",mamba_block_size="None",mamba_cache_dtype="auto",mamba_page_size_padded="None",mamba_ssm_cache_dtype="auto",num_cpu_blocks="None",num_gpu_blocks="98199",num_gpu_blocks_override="None",prefix_caching_hash_algo="sha256",sliding_window="None",swap_space="4.0"} 1.0
        # HELP http_requests_total Total number of requests by method, status and handler.
        # TYPE http_requests_total counter
        http_requests_total{handler="/v1/chat/completions",method="POST",status="2xx"} 23.0
        http_requests_total{handler="/v1/chat/completions",method="POST",status="5xx"} 1.0
        # HELP http_requests_created Total number of requests by method, status and handler.
        # TYPE http_requests_created gauge
        http_requests_created{handler="/v1/chat/completions",method="POST",status="2xx"} 1.7685522193084602e+09
        http_requests_created{handler="/v1/chat/completions",method="POST",status="5xx"} 1.7685522649156253e+09
        # HELP http_request_size_bytes Content length of incoming requests by handler. Only value of header is respected. Otherwise ignored. No percentile calculated. 
        # TYPE http_request_size_bytes summary
        http_request_size_bytes_count{handler="/v1/chat/completions"} 24.0
        http_request_size_bytes_sum{handler="/v1/chat/completions"} 5320.0
        # HELP http_request_size_bytes_created Content length of incoming requests by handler. Only value of header is respected. Otherwise ignored. No percentile calculated. 
        # TYPE http_request_size_bytes_created gauge
        http_request_size_bytes_created{handler="/v1/chat/completions"} 1.7685522193084817e+09
        # HELP http_response_size_bytes Content length of outgoing responses by handler. Only value of header is respected. Otherwise ignored. No percentile calculated. 
        # TYPE http_response_size_bytes summary
        http_response_size_bytes_count{handler="/v1/chat/completions"} 24.0
        http_response_size_bytes_sum{handler="/v1/chat/completions"} 60482.0
        # HELP http_response_size_bytes_created Content length of outgoing responses by handler. Only value of header is respected. Otherwise ignored. No percentile calculated. 
        # TYPE http_response_size_bytes_created gauge
        http_response_size_bytes_created{handler="/v1/chat/completions"} 1.768552219308505e+09
        # HELP http_request_duration_highr_seconds Latency with many buckets but no API specific labels. Made for more accurate percentile calculations. 
        # TYPE http_request_duration_highr_seconds histogram
        http_request_duration_highr_seconds_bucket{le="0.01"} 0.0
        http_request_duration_highr_seconds_bucket{le="0.025"} 0.0
        http_request_duration_highr_seconds_bucket{le="0.05"} 0.0
        http_request_duration_highr_seconds_bucket{le="0.075"} 0.0
        http_request_duration_highr_seconds_bucket{le="0.1"} 0.0
        http_request_duration_highr_seconds_bucket{le="0.25"} 2.0
        http_request_duration_highr_seconds_bucket{le="0.5"} 2.0
        http_request_duration_highr_seconds_bucket{le="0.75"} 6.0
        http_request_duration_highr_seconds_bucket{le="1.0"} 11.0
        http_request_duration_highr_seconds_bucket{le="1.5"} 19.0
        http_request_duration_highr_seconds_bucket{le="2.0"} 21.0
        http_request_duration_highr_seconds_bucket{le="2.5"} 21.0
        http_request_duration_highr_seconds_bucket{le="3.0"} 22.0
        http_request_duration_highr_seconds_bucket{le="3.5"} 22.0
        http_request_duration_highr_seconds_bucket{le="4.0"} 24.0
        http_request_duration_highr_seconds_bucket{le="4.5"} 24.0
        http_request_duration_highr_seconds_bucket{le="5.0"} 24.0
        http_request_duration_highr_seconds_bucket{le="7.5"} 24.0
        http_request_duration_highr_seconds_bucket{le="10.0"} 24.0
        http_request_duration_highr_seconds_bucket{le="30.0"} 24.0
        http_request_duration_highr_seconds_bucket{le="60.0"} 24.0
        http_request_duration_highr_seconds_bucket{le="+Inf"} 24.0
        http_request_duration_highr_seconds_count 24.0
        http_request_duration_highr_seconds_sum 31.219464370136848
        # HELP http_request_duration_highr_seconds_created Latency with many buckets but no API specific labels. Made for more accurate percentile calculations. 
        # TYPE http_request_duration_highr_seconds_created gauge
        http_request_duration_highr_seconds_created 1.768516804113773e+09
        # HELP http_request_duration_seconds Latency with only few buckets by handler. Made to be only used if aggregation by handler is important. 
        # TYPE http_request_duration_seconds histogram
        http_request_duration_seconds_bucket{handler="/v1/chat/completions",le="0.1",method="POST"} 0.0
        http_request_duration_seconds_bucket{handler="/v1/chat/completions",le="0.5",method="POST"} 2.0
        http_request_duration_seconds_bucket{handler="/v1/chat/completions",le="1.0",method="POST"} 11.0
        http_request_duration_seconds_bucket{handler="/v1/chat/completions",le="+Inf",method="POST"} 24.0
        http_request_duration_seconds_count{handler="/v1/chat/completions",method="POST"} 24.0
        http_request_duration_seconds_sum{handler="/v1/chat/completions",method="POST"} 31.219464370136848
        # HELP http_request_duration_seconds_created Latency with only few buckets by handler. Made to be only used if aggregation by handler is important. 
        # TYPE http_request_duration_seconds_created gauge
        http_request_duration_seconds_created{handler="/v1/chat/completions",method="POST"} 1.7685522193085372e+09
"""

# %%
messages = [{"role": "user", "content": request}]

# %%
ollama = OpenAI(base_url='http://10.95.161.240:8000/v1', api_key='ollama')
model_name = "openai/gpt-oss-120b"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
# Out:
# ## TL;DR
#
# | Area | What the numbers say | What you should watch / do |
# |------|----------------------|----------------------------|
# | **Process health** | 1.28 GB RSS, 14 GB virtual memory, 75 open fds (out of a 1 M limit). CPU time ≈ 125 s, no GC‑uncollectable objects. | Memory usage is modest for a 120 B model, but keep an eye on virtual‑memory growth. The FD count is tiny – no leak concerns yet. |
# | **Garbage collection** | Gen‑0 collected ≈ 13 k objects (1 504 collections), Gen‑1 ≈ 1.5 k (137 collections), Gen‑2 ≈ 1.4 k (10 collections). No uncollectable objects. | GC is running normally; the low number of Gen‑2 collections suggests the interpreter is not under pressure. |
# ...
